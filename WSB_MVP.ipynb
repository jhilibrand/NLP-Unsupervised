# %% [markdown]
# # NLP MVP

# %% [markdown]
# The goal of my project is to build a topic model using NLP techniques that is representative of the discussion threads on the subreddit WallStreetBets. My data was primarily scraped from Reddit using PushShift and PRAW, and consists of the top 100 posts per month (and all sub comments), over the first 6 months of the year.
#
# The below is an initial word cloud of this data. This is useful for visualizing what words have been driving discussion across these threads ( for example: 'gme', 'buy', 'hold')

# %%
from IPython.display import Image
Image(filename='word_cloud.png')

# %% [markdown]
# ## Next Steps:
#
# Ideally my next steps would be to:
# * do further time series analysis as to how these topics have shifted over time
# * additional sentiment analysis of these topics
